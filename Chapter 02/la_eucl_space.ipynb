# %%
import matplotlib.pyplot as plt
import numpy as np

X = np.arange(-10, 10, 1)
Y = np.arange(-10, 10, 1)
U, V = np.meshgrid(X, Y)
X = np.array([2,2])
Y = np.array([2,2])
U = np.array([10,2])
V = np.array([2,10])

fig, ax = plt.subplots()
q = ax.quiver(X, Y, U, V)


plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ax = plt.axes()

ax.arrow(0, 0, 3, 4, length_includes_head=True, head_width=0.5, head_length=0.5, ec='orange', overhang=1)
ax.arrow(2, 1, 3, 4, length_includes_head=True, head_width=0.5, head_length=0.5, ec='blue', overhang=1)

# Plot text
ax.text(*np.array((0.2, 0.1)), 'O(0,0)')
ax.text(*np.array((3.1, 4)), 'P(3,4)')
ax.text(*np.array((.5, 0.5)), r'$\bf{u}$=(3-0,4-0)=(3,4)')

ax.text(*np.array((2.1, 1)), 'A(2,1)')
ax.text(*np.array((5.1, 5)), 'B(5,5)')
ax.text(*np.array((4, 3)), r'$\bf{v}$=(5-2,5-1)=(3,4)')
#ax.text(*l2, 'text rotated correctly', fontsize=12, rotation=angle, rotation_mode='anchor',
#              transform_rotates_text=True)

# Point
ax.plot(*np.array((0, 0)), marker="o", c='green', alpha=.5)
ax.plot(*np.array((3, 4)), marker="o", c='green', alpha=.5)
ax.plot(*np.array((2, 1)), marker="o", c='green', alpha=.5)
ax.plot(*np.array((5, 5)), marker="o", c='green', alpha=.5)

# Axis at (0,0)
ax.spines.left.set_position('zero')
ax.spines.bottom.set_position('zero')

# axis limit
plt.xlim(right=9)

# remove border lines
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

plt.show()

# %%
# Direction
import matplotlib.pyplot as plt
import numpy as np

ax = plt.axes()

ax.arrow(0, 0, 3, 4, length_includes_head=True, head_width=0.5, head_length=0.5, ec='orange', overhang=1)
ax.arrow(2, 1, 3, 4, length_includes_head=True, head_width=0.5, head_length=0.5, ec='blue', overhang=1)

# Plot text
ax.text(*np.array((0.1, -0.3)), 'O(0,0)')
ax.text(*np.array((3.1, 4)), 'P(3,4)')
ax.text(*np.array((1, 2.5)), r'$\bf{u}$=(3,4)')
ax.text(*np.array((0.3, .2)), r'$\theta=53.14\degree$')
ax.text(*np.array((2,.05)), '3')
ax.text(*np.array((3,3)), '4')

ax.text(*np.array((2, 0.8)), 'A(2,1)')
ax.text(*np.array((5.1, 5)), 'B(5,5)')
ax.text(*np.array((3.7, 3)), r'$\bf{v}$=(3,4)')
ax.text(*np.array((2.4, 1.2)), r'$\theta=53.14\degree$')
ax.text(*np.array((3.6,.9)), '3')
ax.text(*np.array((5,2.8)), '4')
#ax.text(*l2, 'text rotated correctly', fontsize=12, rotation=angle, rotation_mode='anchor',
#              transform_rotates_text=True)

# Point
ax.plot(*np.array((0, 0)), marker="o", c='green', alpha=.5)
ax.plot(*np.array((3, 4)), marker="o", c='green', alpha=.5)
ax.plot(*np.array((2, 1)), marker="o", c='green', alpha=.5)
ax.plot(*np.array((5, 5)), marker="o", c='green', alpha=.5)

# Line
x_vals=[3,3];y_vals=[0,4]
ax.plot(x_vals, y_vals, linestyle='--',c='green', alpha=.5)
x_vals=[5,5];y_vals=[5,1]
ax.plot(x_vals, y_vals, linestyle='--',c='green', alpha=.5)
x_vals=[2,5];y_vals=[1,1]
ax.plot(x_vals, y_vals, linestyle='--',c='green', alpha=.5)
x_vals=[0,3];y_vals=[0,0]
ax.plot(x_vals, y_vals, linestyle='--',c='green', alpha=.5)

# Angle
ax.annotate("",
            xy=(.18, .24), xycoords='data',
            xytext=(.25, 0), textcoords='data',
            arrowprops=dict(arrowstyle="-",
                            color="0.5",
                            patchA=None,
                            shrinkA=0,shrinkB=0,
                            connectionstyle="arc3,rad=.3",
                            ),
            )
ax.annotate("",
            xy=(2.2, 1.3), xycoords='data',
            xytext=(2.3, 1), textcoords='data',
            arrowprops=dict(arrowstyle="-",
                            color="0.5",
                            patchA=None,
                            shrinkA=0,shrinkB=0,
                            connectionstyle="arc3,rad=.3",
                            ),
            )

# Axis at (0,0)
ax.spines.left.set_position('zero')
ax.spines.bottom.set_position('zero')

# axis limit
plt.xlim(right=9)

# remove border lines
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

plt.show()

# %%
# Addition & Subtraction
import matplotlib.pyplot as plt
import numpy as np

ax = plt.axes()
ax.arrow(0, 0, 2, 8, length_includes_head=True, head_width=0.5, head_length=0.5, ec='purple',
         overhang=1)
ax.arrow(10, 0, 2, 8, length_includes_head=True, head_width=0.5, head_length=0.5, ec='purple',
         ls='--', overhang=1, alpha=.5)
ax.arrow(0, 0, 10, 0, length_includes_head=True, head_width=0.5, head_length=0.5, ec='blue',
         overhang=1)
ax.arrow(2, 8, 10, 0, length_includes_head=True, head_width=0.5, head_length=0.5, ec='blue',
         ls='--', overhang=1, alpha=.5)
ax.arrow(0, 0, 12, 8, length_includes_head=True, head_width=0.5, head_length=0.5, ec='red',
         overhang=1)
ax.arrow(10, 0, -2, -8, length_includes_head=True, head_width=0.5, head_length=0.5, ec='olive',
         ls='--', overhang=1, alpha=.5)
ax.arrow(0, 0, 8, -8, length_includes_head=True, head_width=0.5, head_length=0.5, ec='cyan',
         overhang=1)
ax.arrow(2, 8, 8, -8, length_includes_head=True, head_width=0.5, head_length=0.5, ec='cyan',
         ls='--', overhang=1, alpha=.5)


# Plot text
ax.text(*np.array((5, 0.2)), r'$\bf{u}$')
ax.text(*np.array((7, 8.2)), r'$\bf{u}$')
ax.text(*np.array((0.5, 4)), r'$\bf{v}$')
ax.text(*np.array((9.2, -4)), r'-$\bf{v}$')
ax.text(*np.array((6.5, 4.8)), r'$\bf{u}$+$\bf{v}$', rotation=20)
ax.text(*np.array((10.5, 4)), r'$\bf{v}$')
ax.text(*np.array((4, -5.3)), r'$\bf{u}$-$\bf{v}$', rotation=-30)
ax.text(*np.array((7, 2.5)), r'$\bf{u}$-$\bf{v}$', rotation=-30)
# Plot text about points
ax.text(*np.array((2,8.3)), '(2,8)')
ax.text(*np.array((12,8.3)), '(12,8)')
ax.text(*np.array((10.1,0.2)), '(10,0)')
ax.text(*np.array((8.2,-8)), '(8,-8)')
#ax.text(*np.array((,)), '()')
#ax.text(*l2, 'text rotated correctly', fontsize=12, rotation=angle, rotation_mode='anchor',
#              transform_rotates_text=True)

# Point
ax.plot(*np.array((0,0)), marker="o", c='green', alpha=.5)
ax.plot(*np.array((2,8)), marker="o", c='green', alpha=.5)
ax.plot(*np.array((12,8)), marker="o", c='green', alpha=.5)
ax.plot(*np.array((10,0)), marker="o", c='green', alpha=.5)
ax.plot(*np.array((8,-8 )), marker="o", c='green', alpha=.5)

# Axis at (0,0)
ax.spines.left.set_position('zero')
ax.spines.bottom.set_position('zero')

# remove border lines
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

plt.show()

# %%
# Scalar Multiplication
import matplotlib.pyplot as plt
import numpy as np

ax = plt.axes()

ax.arrow(0, 0, 3, 3, length_includes_head=True, head_width=0.5, head_length=0.5, ec='orange', overhang=1, alpha=0.4)
ax.arrow(0, 0, -3, -3, length_includes_head=True, head_width=0.5, head_length=0.5, ec='red', overhang=1, alpha=0.4)
ax.arrow(0, 0, 6, 6, length_includes_head=True, head_width=0.5, head_length=0.5, ec='green', overhang=1, alpha=0.4)

# Plot text
ax.text(*np.array((1.7, 1.5)), r'$\bf{u}$=(3,3)')
ax.text(*np.array((-3.5, -1.2)), r'$\bf{v}$=(-1)$\bf{u}$=(-3,-3)')
ax.text(*np.array((4.2, 4)), r'$\bf{w}$=2$\bf{u}$=(6,6)')
#ax.text(*l2, 'text rotated correctly', fontsize=12, rotation=angle, rotation_mode='anchor',
#              transform_rotates_text=True)

# Axis at (0,0)
ax.spines.left.set_position('zero')
ax.spines.bottom.set_position('zero')

# remove border lines
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

plt.show()

# %%
# Projection
import matplotlib.pyplot as plt
import numpy as np

ax = plt.axes()

# Arrows
ax.arrow(0, 0, 10, 2, length_includes_head=True, head_width=0.5, head_length=0.5, ec='grey',
         overhang=1, alpha=.5)
ax.arrow(0, 0, 6, 6, length_includes_head=True, head_width=0.5, head_length=0.5, ec='grey',
         overhang=1, alpha=.5)
ax.arrow(0, 0, 6.86, 1.37, length_includes_head=True, head_width=0.5, head_length=0.5, ec='black',
         overhang=1, alpha=.5)
ax.arrow(0, 0, 10, 0, length_includes_head=True, head_width=0.5, head_length=0.5, ec='black',
         overhang=1, alpha=.5)

# Line
x_vals=[6,6.92];y_vals=[6,1.384]
ax.plot(x_vals, y_vals, linestyle='--',c='grey', alpha=1)
x_vals=[10,10];y_vals=[2,0]
ax.plot(x_vals, y_vals, linestyle='--',c='grey', alpha=1)

# Point
ax.plot(*np.array((6.86, 1.37)), marker="o")

# Plot text
ax.text(*np.array((10, 2)), r'$\mathbf{u}=(10,2)$')
ax.text(*np.array((6, 6)), r'$\mathbf{v}=(6,6)$')
ax.text(*np.array((1, .6)), r'$33.7\degree$')
ax.text(*np.array((2, .1)), r'$11.3\degree$')
ax.text(*np.array((5.7, 1.6)), r'$90\degree$')
ax.text(*np.array((9, .3)), r'$90\degree$')
ax.text(*np.array((6.86, 1)), r'$(6.92, 1.38)$')
ax.text(*np.array((2.6,0.7)), r'$\Vert\mathbf{v}\Vert\cos33.7\degree$',  rotation=11.3)
ax.text(*np.array((6.4,3.8)), r'$\Vert\mathbf{v}\Vert\sin33.7\degree$',  rotation=11.3)
ax.text(*np.array((2.5,3)), r'$\Vert\mathbf{v}\Vert=6\sqrt{2}\approx8.4$',  rotation=48)
ax.text(*np.array((6,0.2)), r'$\Vert\mathbf{u}\Vert\cos11.3\degree$')
ax.text(*np.array((10.1,0.8)), r'$\Vert\mathbf{u}\Vert\sin11.3\degree$')
ax.text(*np.array((7.8,1.8)), r'$\Vert\mathbf{u}\Vert=\sqrt{104}\approx10.2$',  rotation=45)
#ax.text(*l2, 'text rotated correctly', fontsize=12, rotation=angle, rotation_mode='anchor',
#              transform_rotates_text=True)

# Axis at (0,0)
ax.spines.left.set_position('zero')
ax.spines.bottom.set_position('zero')

# remove border lines
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

# Angle
# Arc
ax.annotate("",
            xy=(1, .2), xycoords='data',
            xytext=(.75, .75), textcoords='data',
            arrowprops=dict(arrowstyle="-",
                            color="0.5",
                            patchA=None,
                            shrinkA=0,shrinkB=0,
                            connectionstyle="arc3,rad=-.3",
                            ),
            )
ax.annotate("",
            xy=(1.5, .3), xycoords='data',
            xytext=(1.6, 0), textcoords='data',
            arrowprops=dict(arrowstyle="-",
                            color="0.5",
                            patchA=None,
                            shrinkA=0,shrinkB=0,
                            connectionstyle="arc3,rad=.3",
                            ),
            )
# 90 degree angle
ax.annotate("",
            xy=(6.8, 1.7), xycoords='data',
            xytext=(6.51, 1.33), textcoords='data',
            arrowprops=dict(arrowstyle="-",
                            color="0.5",
                            patchA=None,
                            shrinkA=0,shrinkB=0,
                            connectionstyle="angle,angleA=100,angleB=11.3,rad=0",
                            ),
            )
ax.annotate("",
            xy=(10, .3), xycoords='data',
            xytext=(9.7, 0), textcoords='data',
            arrowprops=dict(arrowstyle="-",
                            color="0.5",
                            patchA=None,
                            shrinkA=0,shrinkB=0,
                            connectionstyle="angle,angleA=90,angleB=0,rad=0",
                            ),
            )

# axis limit
plt.xlim(right=12)

plt.show()

# %%
# Linearly Independent
import matplotlib.pyplot as plt
import numpy as np

ax = plt.axes()

ax.arrow(0, 0, 3, 1, length_includes_head=True, head_width=0.5, head_length=0.5, ec='green',
         overhang=1, alpha=0.9)
ax.arrow(0, 0, -3, -1, length_includes_head=True, head_width=0.5, head_length=0.5, ec='green',
         overhang=1, alpha=0.9)
ax.arrow(0, 0, 1, 3, length_includes_head=True, head_width=0.5, head_length=0.5, ec='orange',
         overhang=1, alpha=0.9)
ax.arrow(0, 0, -1, -3, length_includes_head=True, head_width=0.5, head_length=0.5, ec='orange',
         overhang=1, alpha=0.9)

# Line
x_vals=[12,-12];y_vals=[4,-4]
ax.plot(x_vals, y_vals, linestyle='--',c='green', alpha=.9)
x_vals=[4,-4];y_vals=[12,-12]
ax.plot(x_vals, y_vals, linestyle='--',c='orange', alpha=.9)

# Plot text
ax.text(*np.array((3, 0.3)), r'$\mathbf{u}=(3,1)$')
ax.text(*np.array((-4, -2.1)), r'$(-1)\mathbf{u}$')
ax.text(*np.array((1, 3)), r'$\mathbf{v}$=(1,3)')
ax.text(*np.array((-0.5, -3)), r'$(-1)\mathbf{v}$')
#ax.text(*l2, 'text rotated correctly', fontsize=12, rotation=angle, rotation_mode='anchor',
#              transform_rotates_text=True)

# Axis at (0,0)
ax.spines.left.set_position('zero')
ax.spines.bottom.set_position('zero')

# remove border lines
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

plt.show()

# %%
import matplotlib.pyplot as plt


def demo_con_style(ax, connectionstyle):
    x1, y1 = 0.3, 0.2
    x2, y2 = 0.8, 0.6

    ax.plot([x1, x2], [y1, y2], ".")
    ax.annotate("",
                xy=(x1, y1), xycoords='data',
                xytext=(x2, y2), textcoords='data',
                arrowprops=dict(arrowstyle="->", color="0.5",
                                shrinkA=5, shrinkB=5,
                                patchA=None, patchB=None,
                                connectionstyle=connectionstyle,
                                ),
                )

    ax.text(.05, .95, connectionstyle.replace(",", ",\n"),
            transform=ax.transAxes, ha="left", va="top")


fig, axs = plt.subplots(3, 5, figsize=(8, 4.8))
demo_con_style(axs[0, 0], "angle3,angleA=90,angleB=0")
demo_con_style(axs[1, 0], "angle3,angleA=0,angleB=90")
demo_con_style(axs[0, 1], "arc3,rad=0.")
demo_con_style(axs[1, 1], "arc3,rad=0.3")
demo_con_style(axs[2, 1], "arc3,rad=-0.3")
demo_con_style(axs[0, 2], "angle,angleA=-90,angleB=180,rad=0")
demo_con_style(axs[1, 2], "angle,angleA=-90,angleB=180,rad=5")
demo_con_style(axs[2, 2], "angle,angleA=-90,angleB=10,rad=5")
demo_con_style(axs[0, 3], "arc,angleA=-90,angleB=0,armA=30,armB=30,rad=0")
demo_con_style(axs[1, 3], "arc,angleA=-90,angleB=0,armA=30,armB=30,rad=5")
demo_con_style(axs[2, 3], "arc,angleA=-90,angleB=0,armA=0,armB=40,rad=0")
demo_con_style(axs[0, 4], "bar,fraction=0.3")
demo_con_style(axs[1, 4], "bar,fraction=-0.3")
demo_con_style(axs[2, 4], "bar,angle=180,fraction=-0.2")

for ax in axs.flat:
    ax.set(xlim=(0, 1), ylim=(0, 1), xticks=[], yticks=[], aspect=1)
fig.tight_layout(pad=0.2)

plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches


fig, axs = plt.subplots(2, 2)
x1, y1 = 0.3, 0.3
x2, y2 = 0.7, 0.7

ax = axs.flat[0]
ax.plot([x1, x2], [y1, y2], ".")
el = mpatches.Ellipse((x1, y1), 0.3, 0.4, angle=30, alpha=0.2)
ax.add_artist(el)
ax.annotate("",
            xy=(x1, y1), xycoords='data',
            xytext=(x2, y2), textcoords='data',
            arrowprops=dict(arrowstyle="-",
                            color="0.5",
                            patchB=None,
                            shrinkB=0,
                            connectionstyle="arc3,rad=0.3",
                            ),
            )
ax.text(.05, .95, "connect", transform=ax.transAxes, ha="left", va="top")

ax = axs.flat[1]
ax.plot([x1, x2], [y1, y2], ".")
el = mpatches.Ellipse((x1, y1), 0.3, 0.4, angle=30, alpha=0.2)
ax.add_artist(el)
ax.annotate("",
            xy=(x1, y1), xycoords='data',
            xytext=(x2, y2), textcoords='data',
            arrowprops=dict(arrowstyle="-",
                            color="0.5",
                            patchB=el,
                            shrinkB=0,
                            connectionstyle="arc3,rad=0.3",
                            ),
            )
ax.text(.05, .95, "clip", transform=ax.transAxes, ha="left", va="top")

ax = axs.flat[2]
ax.plot([x1, x2], [y1, y2], ".")
el = mpatches.Ellipse((x1, y1), 0.3, 0.4, angle=30, alpha=0.2)
ax.add_artist(el)
ax.annotate("",
            xy=(x1, y1), xycoords='data',
            xytext=(x2, y2), textcoords='data',
            arrowprops=dict(arrowstyle="-",
                            color="0.5",
                            patchB=el,
                            shrinkB=5,
                            connectionstyle="arc3,rad=0.3",
                            ),
            )
ax.text(.05, .95, "shrink", transform=ax.transAxes, ha="left", va="top")

ax = axs.flat[3]
ax.plot([x1, x2], [y1, y2], ".")
el = mpatches.Ellipse((x1, y1), 0.3, 0.4, angle=30, alpha=0.2)
ax.add_artist(el)
ax.annotate("",
            xy=(x1, y1), xycoords='data',
            xytext=(x2, y2), textcoords='data',
            arrowprops=dict(arrowstyle="fancy",
                            color="0.5",
                            patchB=el,
                            shrinkB=5,
                            connectionstyle="arc3,rad=0.3",
                            ),
            )
ax.text(.05, .95, "mutate", transform=ax.transAxes, ha="left", va="top")

for ax in axs.flat:
    ax.set(xlim=(0, 1), ylim=(0, 1), xticks=[], yticks=[], aspect=1)

plt.show()

# %%
import tensorflow as tf

# Norm of vector
# Creation of vector
v = tf.constant([3,4], dtype='float32')
# Calculate euclidean norm
norm_v = tf.norm(v, ord='euclidean')
tf.print("vector v=", v, ", norm of v=", norm_v)

#
# Out:
# vector v= [3 4] ,norm of v= 5

# %%
import tensorflow as tf
import tensorflow_datasets as tfds

# load Iris
iris_ds = tfds.load('iris', split='train')
# Out:
# ...
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-5-ec68108d4566> in <module>
#       3
#       4 # load Iris
# ----> 5 iris_ds = tfds.load('iris', split='train')
#
# c:\users\skbm\anaconda3\envs\mai_py38\lib\site-packages\tensorflow_datasets\core\load.py in load(name, split, data_dir, batch_size, shuffle_files, download, as_supervised, decoders, read_config, with_info, builder_kwargs, download_and_prepare_kwargs, as_dataset_kwargs, try_gcs)
#     326   if download:
#     327     download_and_prepare_kwargs = download_and_prepare_kwargs or {}
# --> 328     dbuilder.download_and_prepare(**download_and_prepare_kwargs)
#     329
#     330   if as_dataset_kwargs is None:
#
# c:\users\skbm\anaconda3\envs\mai_py38\lib\site-packages\tensorflow_datasets\core\dataset_builder.py in download_and_prepare(self, download_dir, download_config)
# ...
