# %%
import matplotlib.pyplot as plt
import numpy as np

ax = plt.axes()

x_vals=[-45,110];y_vals=[-49,230]
ax.plot(x_vals, y_vals,c='black')

# Line
x_vals=[100,100];y_vals=[0,212]
ax.plot(x_vals, y_vals, linestyle='--',c='black', alpha=.5)

# Line
x_vals=[0,100];y_vals=[212,212]
ax.plot(x_vals, y_vals, linestyle='--',c='black', alpha=.5)

# Point
ax.plot(*np.array((100, 212)), marker="o", c='grey')
ax.plot(*np.array((0, 32)), marker="o", c='grey')

# Plot text
ax.text(*np.array((100, 200)), r'$(100,212)$')
ax.text(*np.array((2, 20)), r'$32$')

# Display labels
ax.set_xlabel('Celsius C')
ax.set_ylabel('Fahrenheit F')

# Axis at (0,0)
ax.spines.left.set_position('zero')
ax.spines.bottom.set_position('zero')

# remove border lines
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# create the figure
fig = plt.figure()

# add axes
ax = fig.add_subplot(projection='3d')
axis_b_start = 300; axis_b_end = 500
axis_p_start = 400; axis_p_end = 600

b1, p1 = np.meshgrid(range(axis_b_start, axis_b_end), range(axis_p_start, axis_p_end))
m1 = (1500 - b1 - p1)
# plot the plane
ax.plot_surface(b1, p1, m1, color='cyan', alpha=0.2)

# Display labels
ax.set_xlabel('Bowling Alleys')
ax.set_ylabel('Play Stations')
ax.set_zlabel('Movie Tickets')
#ax.set_title("Plane representing equation1", fontsize='x-large')

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# create the figure
fig = plt.figure()

# add axes
ax = fig.add_subplot(projection='3d')
axis_b_start = 300; axis_b_end = 500
axis_p_start = 400; axis_p_end = 600

# Plane repr eq1
b2, p2 = np.meshgrid(range(axis_b_start, axis_b_end), range(axis_p_start, axis_p_end))
m2 = (4400 - 3*b2 - 4*p2) / 2
# plot the plane
ax.plot_surface(b2, p2, m2, color='red', alpha=0.2)

# Plane repr eq2
b1=b2; p1=p2
m1 = (1500 - b1 - p1)
# plot the plane
ax.plot_surface(b1, p1, m1, color='cyan', alpha=0.4)

# Line in 3D
l_b = np.array(range(300,500))
l_p = (1400-l_b)/2
l_m = l_p + 100
ax.plot3D(l_b, l_p, l_m)

# Display labels
ax.set_xlabel('Bowling Alleys')
ax.set_ylabel('Play Stations')
ax.set_zlabel('Movie Tickets')
#ax.set_title("Line intersection of 2 planes", fontsize='x-large')

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# create the figure
fig = plt.figure()

# add axes
ax = fig.add_subplot(projection='3d')
axis_b_start = 300; axis_b_end = 500
axis_p_start = 400; axis_p_end = 600

b3, p3 = np.meshgrid(range(axis_b_start, axis_b_end), range(axis_p_start, axis_p_end))
m3 = (6500 - 5*b3 - 3*p3) / 5
# plot the plane
ax.plot_surface(b3, p3, m3, color='orange', alpha=0.6)

# Display labels
ax.set_xlabel('Bowling Alleys')
ax.set_ylabel('Play Stations')
ax.set_zlabel('Movie Tickets')

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# create the figure
fig = plt.figure()

# add axes
ax = fig.add_subplot(projection='3d')
axis_b_start = 300; axis_b_end = 500
axis_p_start = 400; axis_p_end = 600

b1, p1 = np.meshgrid(range(axis_b_start, axis_b_end), range(axis_p_start, axis_p_end))
m1 = (1500 - b1 - p1)
# plot the plane
ax.plot_surface(b1, p1, m1, color='cyan', alpha=0.2)

b2 = b1; p2 = p1
m2 = (4400 - 3*b2 - 4*p2) / 2
# plot the plane
ax.plot_surface(b2, p2, m2, color='red', alpha=0.4)

b3 = b1; p3 = p1
m3 = (6500 - 5*b3 - 3*p3) / 5
# plot the plane
ax.plot_surface(b3, p3, m3, color='orange', alpha=0.6)

# Intersection point
ax.scatter(400, 500, 600)
# Intersection point annotation
ax.text(400, 500, 600, "Intersection point\n (400, 500, 600)")

# Display labels
ax.set_xlabel('Bowling Alleys', fontsize='x-large')
ax.set_ylabel('Play Stations', fontsize='x-large')
ax.set_zlabel('Movie Tickets', fontsize='x-large')

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# create the figure
fig = plt.figure()

# add axes
ax = fig.add_subplot(projection='3d')
axis_b_start = 300; axis_b_end = 500
axis_p_start = 400; axis_p_end = 600

# Plane repr eq1
b2, p2 = np.meshgrid(range(axis_b_start, axis_b_end), range(axis_p_start, axis_p_end))
m2 = (4400 - 3*b2 - 4*p2) / 2
# plot the plane
ax.plot_surface(b2, p2, m2, color='red', alpha=0.4)

# Plane repr eq2
b1=b2; p1=p2
m1 = (1500 - b1 - p1)
# plot the plane
ax.plot_surface(b1, p1, m1, color='cyan', alpha=0.4)

# Line in 3D
l_b = np.array(range(300,500))
l_p = (1400-l_b)/2
l_m = l_p + 100
ax.plot3D(l_b, l_p, l_m)

# 3rd plane
b3 = b1; p3 = p1
m3 = (6500 - 5*b3 - 3*p3) / 5
# plot the plane
ax.plot_surface(b3, p3, m3, color='orange', alpha=0.4)

# Intersection point
ax.scatter(400, 500, 600, marker='o')
# Intersection point annotation
ax.text(400, 500, 600, "Intersection point\n (400, 500, 600)")

# Display labels
ax.set_xlabel('Bowling Alleys')
ax.set_ylabel('Play Stations')
ax.set_zlabel('Movie Tickets')
#ax.set_title("Intersection of 3 planes at a point", fontsize='x-large')

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# create the figure
fig = plt.figure(figsize=(30, 10))

axis_b_start = 300; axis_b_end = 500
axis_p_start = 400; axis_p_end = 600

# add axes
ax1 = fig.add_subplot(1, 3, 1, projection='3d')
b1, p1 = np.meshgrid(range(axis_b_start, axis_b_end), range(axis_p_start, axis_p_end))
m1 = (1500 - b1 - p1)
# plot the plane
ax1.plot_surface(b1, p1, m1, color='cyan', alpha=0.2)

# add axes
ax2 = fig.add_subplot(1, 3, 2, projection='3d')
b2 = b1; p2 = p1
m2 = (4400 - 3*b2 - 4*p2) / 2
# plot the plane
ax2.plot_surface(b2, p2, m2, color='red', alpha=0.4)

# add axes
ax3 = fig.add_subplot(1, 3, 3, projection='3d')
b3 = b1; p3 = p1
m3 = (6500 - 5*b3 - 3*p3) / 5
# plot the plane
ax3.plot_surface(b3, p3, m3, color='orange', alpha=0.6)

# Display labels & title
ax1.set_xlabel('Bowling Alleys', fontsize='x-large'); ax1.set_ylabel('Play Stations', fontsize='x-large');
ax1.set_zlabel('Movie Tickets', fontsize='x-large')
ax1.set_title("Group1", fontsize=30)

ax2.set_xlabel('Bowling Alleys', fontsize='x-large');ax2.set_ylabel('Play Stations', fontsize='x-large');
ax2.set_zlabel('Movie Tickets', fontsize='x-large')
ax2.set_title("Group2", fontsize=30)

ax3.set_xlabel('Bowling Alleys', fontsize='x-large');ax3.set_ylabel('Play Stations', fontsize='x-large');
ax3.set_zlabel('Movie Tickets', fontsize='x-large')
ax3.set_title("Group3", fontsize=30)

plt.show()

# %%
# Infinite number of solutions
import numpy as np
import matplotlib.pyplot as plt

# create the figure
fig = plt.figure()

# add axes
ax = fig.add_subplot(projection='3d')
axis_b_start = 300; axis_b_end = 500
axis_p_start = 400; axis_p_end = 600

b1, p1 = np.meshgrid(range(axis_b_start, axis_b_end), range(axis_p_start, axis_p_end))
m1 = (1500 - b1 - p1)
# plot the plane
ax.plot_surface(b1, p1, m1, color='cyan', alpha=0.4)

b3, p3 = np.meshgrid(range(axis_b_start-20, axis_b_end+20), range(axis_p_start-20, axis_p_end+20))
m3 = (3000 - 2*b3 - 2*p3) / 2
# plot the plane
ax.plot_surface(b3, p3, m3, color='orange', alpha=0.2)

# Display labels
ax.set_xlabel('Bowling Alleys', fontsize='x-large')
ax.set_ylabel('Play Stations', fontsize='x-large')
ax.set_zlabel('Movie Tickets', fontsize='x-large')
ax.set_title("2 planes overlapping", fontsize='x-large')
plt.show()

# %%
# Infinite number of solutions
import numpy as np
import matplotlib.pyplot as plt

# create the figure
fig = plt.figure()

# add axes
ax = fig.add_subplot(projection='3d')
axis_b_start = 300; axis_b_end = 500
axis_p_start = 400; axis_p_end = 600

b1, p1 = np.meshgrid(range(axis_b_start, axis_b_end), range(axis_p_start, axis_p_end))
m1 = (1500 - b1 - p1)
# plot the plane
ax.plot_surface(b1, p1, m1, color='cyan', alpha=0.4)

b2 = b1; p2 = p1
m2 = (4400 - 3*b2 - 4*p2) / 2
# plot the plane
ax.plot_surface(b2, p2, m2, color='red', alpha=0.2)

b3, p3 = np.meshgrid(range(axis_b_start-20, axis_b_end+20), range(axis_p_start-20, axis_p_end+20))
m3 = (3000 - 2*b3 - 2*p3) / 2
# plot the plane
ax.plot_surface(b3, p3, m3, color='orange', alpha=0.2)

# Line in 3D
l_b = np.array(range(300,500))
l_p = (1400-l_b)/2
l_m = l_p + 100
ax.plot3D(l_b, l_p, l_m)

# Display labels
ax.set_xlabel('Bowling Alleys', fontsize='x-large')
ax.set_ylabel('Play Stations', fontsize='x-large')
ax.set_zlabel('Movie Tickets', fontsize='x-large')
ax.set_title("Intersection of 2 overlapping planes with third plane along line", fontsize='x-large')
plt.show()

# %%
# No solutions
import numpy as np
import matplotlib.pyplot as plt

# create the figure
fig = plt.figure()

# add axes
ax = fig.add_subplot(projection='3d')
axis_b_start = 300; axis_b_end = 500
axis_p_start = 400; axis_p_end = 600

b1, p1 = np.meshgrid(range(axis_b_start, axis_b_end), range(axis_p_start, axis_p_end))
m1 = (1500 - b1 - p1)
# plot the plane
ax.plot_surface(b1, p1, m1, color='cyan', alpha=0.4)

b3 = b1; p3 = p1
m3 = (2000 - 2*b3 - 2*p3) / 2
# plot the plane
ax.plot_surface(b3, p3, m3, color='orange', alpha=0.4)

# Display labels
ax.set_xlabel('Bowling Alleys', fontsize='x-large')
ax.set_ylabel('Play Stations', fontsize='x-large')
ax.set_zlabel('Movie Tickets', fontsize='x-large')
ax.set_title("Parallel planes", fontsize='x-large')

plt.show()

# %%
# Infinite number of solutions
import numpy as np
import matplotlib.pyplot as plt

# create the figure
fig = plt.figure()

# add axes
ax = fig.add_subplot(projection='3d')
axis_b_start = 300; axis_b_end = 500
axis_p_start = 400; axis_p_end = 600

b1, p1 = np.meshgrid(range(axis_b_start, axis_b_end), range(axis_p_start, axis_p_end))
m1 = (1500 - b1 - p1)
# plot the plane
ax.plot_surface(b1, p1, m1, color='cyan', alpha=0.4)

b2 = b1; p2 = p1
m2 = (4400 - 3*b2 - 4*p2) / 2
# plot the plane
ax.plot_surface(b2, p2, m2, color='red', alpha=0.4)

b3 = b1; p3 = p1
m3 = (2000 - 2*b3 - 2*p3) / 2
# plot the plane
ax.plot_surface(b3, p3, m3, color='orange', alpha=0.4)

# Display labels
ax.set_xlabel('Bowling Alleys', fontsize='x-large')
ax.set_ylabel('Play Stations', fontsize='x-large')
ax.set_zlabel('Movie Tickets', fontsize='x-large')
ax.set_title("3 planes do not intersect at single point", fontsize='x-large')

plt.show()

# %%
# Hyperplane & Halfspaces
import matplotlib.pyplot as plt
import numpy as np

ax = plt.axes()

# Line
x_vals=[-6,9];y_vals=[6,-4]
ax.plot(x_vals, y_vals,c='black')

# Arrows
ax.arrow(1.5, 1, 2, 3, length_includes_head=True, head_width=0.5, head_length=0.5, ec='black',
         overhang=1, alpha=1)

# Plot text
#ax.text(*np.array((5.4, -1.3)), r'$2x+3y=6$')
#ax.text(*np.array((0.12, 2.6)), r'$2x+3y>6$')
#ax.text(*np.array((-4, 2)), r'$2x+3y<6$')

# Axis at (0,0)
ax.spines.left.set_position('zero')
ax.spines.bottom.set_position('zero')

# remove border lines
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

plt.show()
